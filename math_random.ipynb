# %%
import math
import random

liste = []

for _ in range(1000):
    x = random.randint(1, 6)
    liste.append(x)
    
import matplotlib.pyplot as plt

plt.hist(liste)
# Out:
# (array([159.,   0., 164.,   0., 174.,   0., 173.,   0., 171., 159.]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]),
#  <BarContainer object of 10 artists>)
